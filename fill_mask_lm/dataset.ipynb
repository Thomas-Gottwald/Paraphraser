# %%
import pandas as pd
import seaborn as sns

# %%
def plot_original_POS(df_dataset):
    df = df_dataset.reset_index().groupby('og_POS').agg({'chosen': 'sum'}).rename(columns={'chosen': 'count'})
    df.plot.bar()

def plot_suggested_POS(df_dataset):
    df = df_dataset.reset_index().groupby('POS').agg({'suggested': 'sum'})
    df.plot.bar()

def plot_chosen_POS(df_dataset):
    df = df_dataset.reset_index().groupby('POS').agg({'chosen': 'sum'})
    df.plot.bar()

def plot_POS_dependenc(df_dataset, POS_tag, chosen=False):
    kind = 'suggested'
    if chosen:
        kind = 'chosen'
    df_dataset.query("og_POS == '{}'".format(POS_tag))[[kind]].plot.bar()

def plot_POS_heatmap(df_dataset, chosen=False):
    kind = 'suggested'
    if chosen:
        kind = 'chosen'
    df = df_dataset[[kind]].unstack(level=-1)
    df.div(df.sum(axis=1), axis=0)
    sns.heatmap(df.div(df.sum(axis=1), axis=0), cmap="viridis")

# %%
def avg_score(df_dataset, chosen=False):
    kind = 'suggested'
    kind_score = 'avg_sug_score'
    if chosen:
        kind = 'chosen'
        kind_score = 'avg_cho_score'
    print((df_dataset[kind_score]*df_dataset[kind]).sum()/df_dataset[kind].sum())

# %% [markdown]
# # RoBERTa

# %% [markdown]
# # Wikipedia

# %%
df_path = './../data/wikipedia/sp(roberta-large,0.5)/dataset.pkl'
df_dataset = pd.read_pickle(df_path)
df_dataset
# Out:
#               suggested  avg_sug_score  chosen  avg_cho_score
# og_POS POS
# ADJ    ADJ       605544       0.180155  112143       0.250269
#        ADP         6937       0.119328    1670       0.319146
#        ADV        17374       0.090586    3685       0.250445
#        AUX          560       0.121681     146       0.303536
#        CCONJ       2051       0.129540     532       0.324507
# ...                 ...            ...     ...            ...
# X      SCONJ          3       0.057357       0            NaN
#        SPACE          4       0.264289       0            NaN
#        SYM            3       0.264527       1       0.523467
#        VERB          94       0.064836      18       0.198648
#        X            546       0.428101      61       0.118002
#
# [290 rows x 4 columns]

# %%
plot_original_POS(df_dataset)

# %%
plot_suggested_POS(df_dataset)

# %%
plot_chosen_POS(df_dataset)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=False)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=True)

# %%
plot_POS_heatmap(df_dataset, chosen=False)

# %%
plot_POS_heatmap(df_dataset, chosen=True)

# %% [markdown]
# # ARXIV

# %%
df_path = './../data/arxiv/sp(roberta-large,0.5)/dataset.pkl'
df_dataset = pd.read_pickle(df_path)
df_dataset
# Out:
#               suggested  avg_sug_score  chosen  avg_cho_score
# og_POS POS
# ADJ    ADJ       472659       0.154907   86855       0.233701
#        ADP         6975       0.108386    1510       0.299534
#        ADV        12219       0.086361    2419       0.235970
#        AUX          464       0.143445     138       0.342455
#        CCONJ       2805       0.109857     637       0.300124
# ...                 ...            ...     ...            ...
# X      SCONJ          9       0.159658       3       0.310340
#        SPACE         18       0.154423       5       0.338405
#        SYM            4       0.049652       0            NaN
#        VERB          71       0.057256      16       0.106454
#        X           1404       0.450391     106       0.095558
#
# [292 rows x 4 columns]

# %%
plot_original_POS(df_dataset)

# %%
plot_suggested_POS(df_dataset)

# %%
plot_chosen_POS(df_dataset)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=False)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=True)

# %%
plot_POS_heatmap(df_dataset, chosen=False)

# %%
plot_POS_heatmap(df_dataset, chosen=True)

# %% [markdown]
# # Thesis

# %%
df_path = './../data/thesis/sp(roberta-large,0.5)/dataset.pkl'
df_dataset = pd.read_pickle(df_path)
df_dataset
# Out:
#               suggested  avg_sug_score  chosen  avg_cho_score
# og_POS POS
# ADJ    ADJ        93094       0.171854   16726       0.240837
#        ADP         1483       0.121846     352       0.327362
#        ADV         2523       0.085723     522       0.226629
#        AUX          156       0.129663      40       0.316202
#        CCONJ        550       0.121370     128       0.331960
# ...                 ...            ...     ...            ...
# X      PROPN        229       0.024063      53       0.053071
#        PUNCT         82       0.012311      24       0.030795
#        SCONJ          5       0.072521       2       0.000200
#        VERB          29       0.094920       8       0.241477
#        X            409       0.523853      10       0.177792
#
# [273 rows x 4 columns]

# %%
plot_original_POS(df_dataset)

# %%
plot_suggested_POS(df_dataset)

# %%
plot_chosen_POS(df_dataset)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=False)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=True)

# %%
plot_POS_heatmap(df_dataset, chosen=False)

# %%
plot_POS_heatmap(df_dataset, chosen=True)

# %% [markdown]
# # BART

# %% [markdown]
# # Wikipedia

# %%
df_path = './../data/wikipedia/sp(facebook_bart-large,0.5)/dataset.pkl'
df_dataset = pd.read_pickle(df_path)
df_dataset
# Out:
#               suggested  avg_sug_score  chosen  avg_cho_score
# og_POS POS
# ADJ    ADJ       341968       0.129142   56646       0.183116
#        ADP        31040       0.093389    6906       0.226308
#        ADV        29282       0.071318    5321       0.175494
#        AUX         7217       0.083011    1664       0.176648
#        CCONJ      19853       0.103544    5498       0.234367
# ...                 ...            ...     ...            ...
# X      SCONJ         10       0.023918       3       0.050021
#        SPACE         19       0.272048       0            NaN
#        SYM            1       0.227816       1       0.227816
#        VERB          37       0.063526       6       0.230279
#        X            440       0.276129      54       0.138197
#
# [293 rows x 4 columns]

# %%
plot_original_POS(df_dataset)

# %%
plot_suggested_POS(df_dataset)

# %%
plot_chosen_POS(df_dataset)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=False)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=True)

# %%
plot_POS_heatmap(df_dataset, chosen=False)

# %%
plot_POS_heatmap(df_dataset, chosen=True)

# %% [markdown]
# # ARXIV

# %%
df_path = './../data/arxiv/sp(facebook_bart-large,0.5)/dataset.pkl'
df_dataset = pd.read_pickle(df_path)
df_dataset
# Out:
#               suggested  avg_sug_score  chosen  avg_cho_score
# og_POS POS
# ADJ    ADJ       252636       0.113608   42194       0.169962
#        ADP        25095       0.085060    4771       0.220542
#        ADV        21153       0.062937    3398       0.155115
#        AUX         7422       0.085351    1983       0.170975
#        CCONJ      24524       0.106539    6547       0.253445
# ...                 ...            ...     ...            ...
# X      SCONJ         27       0.062488       4       0.162425
#        SPACE         36       0.433412       5       0.255498
#        SYM           15       0.030631       3       0.060255
#        VERB          24       0.059693       3       0.189237
#        X            824       0.379765      65       0.033671
#
# [295 rows x 4 columns]

# %%
plot_original_POS(df_dataset)

# %%
plot_suggested_POS(df_dataset)

# %%
plot_chosen_POS(df_dataset)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=False)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=True)

# %%
plot_POS_heatmap(df_dataset, chosen=False)

# %%
plot_POS_heatmap(df_dataset, chosen=True)

# %% [markdown]
# # Thesis

# %%
df_path = './../data/thesis/sp(facebook_bart-large,0.5)/dataset.pkl'
df_dataset = pd.read_pickle(df_path)
df_dataset
# Out:
#               suggested  avg_sug_score  chosen  avg_cho_score
# og_POS POS
# ADJ    ADJ        51819       0.127423    8319       0.184545
#        ADP         5188       0.086581    1003       0.233280
#        ADV         4766       0.070591     841       0.175585
#        AUX         1358       0.077549     299       0.175135
#        CCONJ       3304       0.076429     802       0.160116
# ...                 ...            ...     ...            ...
# X      SCONJ         15       0.022939       1       0.105526
#        SPACE          3       0.181447       2       0.232515
#        SYM            1       0.000762       0            NaN
#        VERB          20       0.071503       4       0.201282
#        X            233       0.273572       3       0.021831
#
# [285 rows x 4 columns]

# %%
plot_original_POS(df_dataset)

# %%
plot_suggested_POS(df_dataset)

# %%
plot_chosen_POS(df_dataset)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=False)

# %%
plot_POS_dependenc(df_dataset, 'NOUN', chosen=True)

# %%
plot_POS_heatmap(df_dataset, chosen=False)

# %%
plot_POS_heatmap(df_dataset, chosen=True)
